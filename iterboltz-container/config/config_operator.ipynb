# %% [markdown]
# # Create config files

# %% [markdown]
# ### General functions

# %%
import configparser 
"""
[main]
id = 1
path = ./examples/
experiment_id = 1

[setting]
method = only_shift

[examples]
pcf = True
example = ./examples/example2_pcf.pickle
example_id = 2
beta = 1000
size = 8
hardcore = 0.1

[ibi]
gamma = 0.04
gamma0 = 1
alpha = 0.
r_switch = 1.2
dr = 0.02
rdf_cutoff = 1.5
nstates = 8
niter = 100
nreps = 2000
"""

# create initial params dict # on laptop
# params = {
#     "id": 1,
#     "path": "./examples/",
#     "experiment_id": 1,
#     "method": "only_shift",
#     "pcf": True,
#     "example": "./examples/example2_pcf.pickle",
#     "beta": 1000,
#     "size": 8,
#     "gamma": 0.04,
#     "gamma0": 1,
#     "alpha": 0.,
#     "r_switch": 1.2,
#     "dr": 0.02,
#     "rdf_cutoff": 1.5,
#     "nstates": 8,
#     "niter": 200,
#     "nreps": 2000,
#     "configPath": None,
# 	"configName": "config.ini"
# }

# params for cluster
params = {
    "id": 1,
    "path": "/usr/users/weber165/iterboltz-container/calculations/examples/",
    "experiment_id": 2,
    "method": "only_shift",
    "pcf": False,
    "example": "/usr/users/weber165/iterboltz-container/calculations/examples/example1_pcf.pickle",
    "pattern_index": False,
    "hardcore": 0.0,
    "beta": 1000,
    "size": 8,
    "gamma": 0.04,
    "gamma0": 1,
    "alpha": 0.,
    "r_switch": 1.2,
    "dr": 0.02,

    "rdf_cutoff": 1.5,
    "nstates": 8,
    "niter": 100,
    "nreps": 2000,
    "configPath": None,
	"configName": "config.ini"
}


def create_config(params):
    configPath = params['configPath'] #'./config.ini'
    config = configparser.ConfigParser()
    config.read(configPath)

	# set config arguments - general
    try: config.add_section('main')
    except: pass
    config['main']['id'] = str(params['id'])
    config['main']['path'] = str(params['path'])
    config['main']['experiment_id'] = str(params['experiment_id'])

	# set config arguments - data
    try: config.add_section('setting')
    except: pass
    config['setting']['method'] = str(params["method"]) #"only_shift"
    
    try: config.add_section('examples')
    except: pass
    config['examples']['pcf'] = str(params["pcf"]) #"0.3"
    config['examples']['example'] = str(params["example"]) #"0.3"
    config['examples']['example_id'] = str(params["example_id"]) #"0.3"
    config['examples']['pattern_index'] = str(params["pattern_index"]) #"0.3"
    config['examples']['beta'] = str(params["beta"]) #"0.3"
    config['examples']['size'] = str(params["size"]) #"0.3"
    config['examples']['hardcore'] = str(params["hardcore"]) #"0.3"

    try: config.add_section('ibi')
    except: pass
    config['ibi']['gamma'] = str(params["gamma"]) #"0.3"
    config['ibi']['gamma0'] = str(params["gamma0"]) #"0.3"
    config['ibi']['alpha'] = str(params["alpha"]) #"0.3"
    config['ibi']['r_switch'] = str(params["r_switch"]) #"0.3"
    config['ibi']['dr'] = str(params["dr"]) #"0.3"
    config['ibi']['rdf_cutoff'] = str(params["rdf_cutoff"]) #"0.3"
    config['ibi']['nstates'] = str(params["nstates"]) #"0.3"
    config['ibi']['niter'] = str(params["niter"]) #"0.3"
    config['ibi']['nreps'] = str(params["nreps"]) #"0.3"

    with open(configPath, 'w') as configfile:
        config.write(configfile)

# %% [markdown]
# ### IBI for the three pairwise interaction processes

# %%
import numpy as np

#gamma_scale = [1., 0.7, 0.5, 0.3, 0.1, 0.07, 0.05, 0.03, 0.01, 0.005]
#gamma_scale = [0.1, 0.05, 0.01, 0.05, 0.005]
gamma_scale = [0.05]
pattern_index = list(np.arange(100))
rdf_cutoffs = [1.5]
examples = [
    {"example": "/usr/users/weber165/iterboltz-container/calculations/examples/example1_pcf.pickle", 
     "example_id": 1, 
     "beta": 500, 
     "size": 8, 
     "hardcore": 0.1},
    {"example": "/usr/users/weber165/iterboltz-container/calculations/examples/example2_pcf.pickle", 
     "example_id": 2, 
     "beta": 500, 
     "size": 8, 
     "hardcore": 0.1},
    {"example": "/usr/users/weber165/iterboltz-container/calculations/examples/example3_pcf.pickle", 
     "example_id": 3, 
     "beta": 500, 
     "size": 12, 
     "hardcore": 0.1},
]

id_counter = 0
for gamma in gamma_scale:
    for example in examples:
        for rdf_cutoff in rdf_cutoffs:
            for pidx in pattern_index:
                id_counter += 1
                params["id"] = id_counter
                params["gamma"] = gamma
                params["example"] = example["example"]
                params["example_id"] = example["example_id"]
                params["pattern_index"] = pidx
                params["beta"] = example["beta"]
                params["size"] = example["size"]
                params["hardcore"] = example["hardcore"]
                params["rdf_cutoff"] = rdf_cutoff
                params["configPath"] = f"./config{id_counter}.ini"
                create_config(params)
                print("Created config file: {}".format(params["configPath"]))
# Out:
# Created config file: ./config1.ini
# Created config file: ./config2.ini
# Created config file: ./config3.ini
# Created config file: ./config4.ini
# Created config file: ./config5.ini
# Created config file: ./config6.ini
# Created config file: ./config7.ini
# Created config file: ./config8.ini
# Created config file: ./config9.ini
# Created config file: ./config10.ini
# Created config file: ./config11.ini
# Created config file: ./config12.ini
# Created config file: ./config13.ini
# Created config file: ./config14.ini
# Created config file: ./config15.ini
# Created config file: ./config16.ini
# Created config file: ./config17.ini
# Created config file: ./config18.ini
# Created config file: ./config19.ini
# Created config file: ./config20.ini
# Created config file: ./config21.ini
# Created config file: ./config22.ini
# Created config file: ./config23.ini
# Created config file: ./config24.ini
# Created config file: ./config25.ini
# Created config file: ./config26.ini
# Created config file: ./config27.ini
# Created config file: ./config28.ini
# Created config file: ./config29.ini
# Created config file: ./config30.ini
# Created config file: ./config31.ini
# Created config file: ./config32.ini
# Created config file: ./config33.ini
# Created config file: ./config34.ini
# Created config file: ./config35.ini
# Created config file: ./config36.ini
# Created config file: ./config37.ini
# Created config file: ./config38.ini
# Created config file: ./config39.ini
# Created config file: ./config40.ini
# Created config file: ./config41.ini
# Created config file: ./config42.ini
# Created config file: ./config43.ini
# Created config file: ./config44.ini
# Created config file: ./config45.ini
# Created config file: ./config46.ini
# Created config file: ./config47.ini
# Created config file: ./config48.ini
# Created config file: ./config49.ini
# Created config file: ./config50.ini
# Created config file: ./config51.ini
# Created config file: ./config52.ini
# Created config file: ./config53.ini
# Created config file: ./config54.ini
# Created config file: ./config55.ini
# Created config file: ./config56.ini
# Created config file: ./config57.ini
# Created config file: ./config58.ini
# Created config file: ./config59.ini
# Created config file: ./config60.ini
# Created config file: ./config61.ini
# Created config file: ./config62.ini
# Created config file: ./config63.ini
# Created config file: ./config64.ini
# Created config file: ./config65.ini
# Created config file: ./config66.ini
# Created config file: ./config67.ini
# Created config file: ./config68.ini
# Created config file: ./config69.ini
# Created config file: ./config70.ini
# Created config file: ./config71.ini
# Created config file: ./config72.ini
# Created config file: ./config73.ini
# Created config file: ./config74.ini
# Created config file: ./config75.ini
# Created config file: ./config76.ini
# Created config file: ./config77.ini
# Created config file: ./config78.ini
# Created config file: ./config79.ini
# Created config file: ./config80.ini
# Created config file: ./config81.ini
# Created config file: ./config82.ini
# Created config file: ./config83.ini
# Created config file: ./config84.ini
# Created config file: ./config85.ini
# Created config file: ./config86.ini
# Created config file: ./config87.ini
# Created config file: ./config88.ini
# Created config file: ./config89.ini
# Created config file: ./config90.ini
# Created config file: ./config91.ini
# Created config file: ./config92.ini
# Created config file: ./config93.ini
# Created config file: ./config94.ini
# Created config file: ./config95.ini
# Created config file: ./config96.ini
# Created config file: ./config97.ini
# Created config file: ./config98.ini
# Created config file: ./config99.ini
# Created config file: ./config100.ini
# Created config file: ./config101.ini
# Created config file: ./config102.ini
# Created config file: ./config103.ini
# Created config file: ./config104.ini
# Created config file: ./config105.ini
# Created config file: ./config106.ini
# Created config file: ./config107.ini
# Created config file: ./config108.ini
# Created config file: ./config109.ini
# Created config file: ./config110.ini
# Created config file: ./config111.ini
# Created config file: ./config112.ini
# Created config file: ./config113.ini
# Created config file: ./config114.ini
# Created config file: ./config115.ini
# Created config file: ./config116.ini
# Created config file: ./config117.ini
# Created config file: ./config118.ini
# Created config file: ./config119.ini
# Created config file: ./config120.ini
# Created config file: ./config121.ini
# Created config file: ./config122.ini
# Created config file: ./config123.ini
# Created config file: ./config124.ini
# Created config file: ./config125.ini
# Created config file: ./config126.ini
# Created config file: ./config127.ini
# Created config file: ./config128.ini
# Created config file: ./config129.ini
# Created config file: ./config130.ini
# Created config file: ./config131.ini
# Created config file: ./config132.ini
# Created config file: ./config133.ini
# Created config file: ./config134.ini
# Created config file: ./config135.ini
# Created config file: ./config136.ini
# Created config file: ./config137.ini
# Created config file: ./config138.ini
# Created config file: ./config139.ini
# Created config file: ./config140.ini
# Created config file: ./config141.ini
# Created config file: ./config142.ini
# Created config file: ./config143.ini
# Created config file: ./config144.ini
# Created config file: ./config145.ini
# Created config file: ./config146.ini
# Created config file: ./config147.ini
# Created config file: ./config148.ini
# Created config file: ./config149.ini
# Created config file: ./config150.ini
# Created config file: ./config151.ini
# Created config file: ./config152.ini
# Created config file: ./config153.ini
# Created config file: ./config154.ini
# Created config file: ./config155.ini
# Created config file: ./config156.ini
# Created config file: ./config157.ini
# Created config file: ./config158.ini
# Created config file: ./config159.ini
# Created config file: ./config160.ini
# Created config file: ./config161.ini
# Created config file: ./config162.ini
# Created config file: ./config163.ini
# Created config file: ./config164.ini
# Created config file: ./config165.ini
# Created config file: ./config166.ini
# Created config file: ./config167.ini
# Created config file: ./config168.ini
# Created config file: ./config169.ini
# Created config file: ./config170.ini
# Created config file: ./config171.ini
# Created config file: ./config172.ini
# Created config file: ./config173.ini
# Created config file: ./config174.ini
# Created config file: ./config175.ini
# Created config file: ./config176.ini
# Created config file: ./config177.ini
# Created config file: ./config178.ini
# Created config file: ./config179.ini
# Created config file: ./config180.ini
# Created config file: ./config181.ini
# Created config file: ./config182.ini
# Created config file: ./config183.ini
# Created config file: ./config184.ini
# Created config file: ./config185.ini
# Created config file: ./config186.ini
# Created config file: ./config187.ini
# Created config file: ./config188.ini
# Created config file: ./config189.ini
# Created config file: ./config190.ini
# Created config file: ./config191.ini
# Created config file: ./config192.ini
# Created config file: ./config193.ini
# Created config file: ./config194.ini
# Created config file: ./config195.ini
# Created config file: ./config196.ini
# Created config file: ./config197.ini
# Created config file: ./config198.ini
# Created config file: ./config199.ini
# Created config file: ./config200.ini
# Created config file: ./config201.ini
# Created config file: ./config202.ini
# Created config file: ./config203.ini
# Created config file: ./config204.ini
# Created config file: ./config205.ini
# Created config file: ./config206.ini
# Created config file: ./config207.ini
# Created config file: ./config208.ini
# Created config file: ./config209.ini
# Created config file: ./config210.ini
# Created config file: ./config211.ini
# Created config file: ./config212.ini
# Created config file: ./config213.ini
# Created config file: ./config214.ini
# Created config file: ./config215.ini
# Created config file: ./config216.ini
# Created config file: ./config217.ini
# Created config file: ./config218.ini
# Created config file: ./config219.ini
# Created config file: ./config220.ini
# Created config file: ./config221.ini
# Created config file: ./config222.ini
# Created config file: ./config223.ini
# Created config file: ./config224.ini
# Created config file: ./config225.ini
# Created config file: ./config226.ini
# Created config file: ./config227.ini
# Created config file: ./config228.ini
# Created config file: ./config229.ini
# Created config file: ./config230.ini
# Created config file: ./config231.ini
# Created config file: ./config232.ini
# Created config file: ./config233.ini
# Created config file: ./config234.ini
# Created config file: ./config235.ini
# Created config file: ./config236.ini
# Created config file: ./config237.ini
# Created config file: ./config238.ini
# Created config file: ./config239.ini
# Created config file: ./config240.ini
# Created config file: ./config241.ini
# Created config file: ./config242.ini
# Created config file: ./config243.ini
# Created config file: ./config244.ini
# Created config file: ./config245.ini
# Created config file: ./config246.ini
# Created config file: ./config247.ini
# Created config file: ./config248.ini
# Created config file: ./config249.ini
# Created config file: ./config250.ini
# Created config file: ./config251.ini
# Created config file: ./config252.ini
# Created config file: ./config253.ini
# Created config file: ./config254.ini
# Created config file: ./config255.ini
# Created config file: ./config256.ini
# Created config file: ./config257.ini
# Created config file: ./config258.ini
# Created config file: ./config259.ini
# Created config file: ./config260.ini
# Created config file: ./config261.ini
# Created config file: ./config262.ini
# Created config file: ./config263.ini
# Created config file: ./config264.ini
# Created config file: ./config265.ini
# Created config file: ./config266.ini
# Created config file: ./config267.ini
# Created config file: ./config268.ini
# Created config file: ./config269.ini
# Created config file: ./config270.ini
# Created config file: ./config271.ini
# Created config file: ./config272.ini
# Created config file: ./config273.ini
# Created config file: ./config274.ini
# Created config file: ./config275.ini
# Created config file: ./config276.ini
# Created config file: ./config277.ini
# Created config file: ./config278.ini
# Created config file: ./config279.ini
# Created config file: ./config280.ini
# Created config file: ./config281.ini
# Created config file: ./config282.ini
# Created config file: ./config283.ini
# Created config file: ./config284.ini
# Created config file: ./config285.ini
# Created config file: ./config286.ini
# Created config file: ./config287.ini
# Created config file: ./config288.ini
# Created config file: ./config289.ini
# Created config file: ./config290.ini
# Created config file: ./config291.ini
# Created config file: ./config292.ini
# Created config file: ./config293.ini
# Created config file: ./config294.ini
# Created config file: ./config295.ini
# Created config file: ./config296.ini
# Created config file: ./config297.ini
# Created config file: ./config298.ini
# Created config file: ./config299.ini
# Created config file: ./config300.ini

# %% [markdown]
# ### For the tree data

# %% [markdown]
# **pinnatum** \
# nodes 134 \
# hardcore 1.1313567078512432 \
# **copaia** \
# nodes 153 \
# hardcore 0.4840041322138025 \
# **coloradoensis** \
# nodes 164 \
# hardcore 1.0770292475601588 \
# **exorrhiza** \
# nodes 355 \
# hardcore 0.22362468647266306 \
# **macrophyllum** \
# nodes 136 \
# hardcore 0.5932528972537878 \
# **insignis** \
# nodes 846 \
# hardcore 0.1887326150934161 \
# **obtusifolia** \
# nodes 167 \
# hardcore 0.31061873736141066 \
# **superba** \
# nodes 134 \
# hardcore 0.40001000000000886 \
# **ekmanii** \
# nodes 160 \
# hardcore 0.2828427124746155

# %%
# Selected species
selected_species = [
    "pinnatum",
    "copaia",
    "coloradoensis",
    "exorrhiza",
    "macrophyllum",
    "exorrhiza",
    "insignis",
    "obtusifolia",
    "superba",
    "ekmanii"
]

size = 400
gamma_scale = [0.05, 0.01]
activity_range = [50, 100, 250, 500, 750, 1000, 1500, 2000]

# %%
id_counter = 0
for gamma in gamma_scale:
    for activity in activity_range:
        for id, specie in enumerate(selected_species):
            id_counter += 1
            params["id"] = id_counter
            params["gamma"] = gamma
            params["example"] = "./examples/bci/{}_example.pickle".format(specie)
            params["path"] = "./examples/"
            params["example_id"] = id
            params["experiment_id"] = 3
            params["pattern_index"] = "False"
            params["beta"] = activity
            params["size"] = size
            params["hardcore"] = 0.11
            params["rdf_cutoff"] = 100
            params["r_switch"] = 80
            params["dr"] = 0.1
            params["niter"] = 100
            params["configPath"] = f"./config{id_counter}.ini"
            create_config(params)
            print("Created config file: {}".format(params["configPath"]))
# Out:
# Created config file: ./config1.ini
# Created config file: ./config2.ini
# Created config file: ./config3.ini
# Created config file: ./config4.ini
# Created config file: ./config5.ini
# Created config file: ./config6.ini
# Created config file: ./config7.ini
# Created config file: ./config8.ini
# Created config file: ./config9.ini
# Created config file: ./config10.ini
# Created config file: ./config11.ini
# Created config file: ./config12.ini
# Created config file: ./config13.ini
# Created config file: ./config14.ini
# Created config file: ./config15.ini
# Created config file: ./config16.ini
# Created config file: ./config17.ini
# Created config file: ./config18.ini
# Created config file: ./config19.ini
# Created config file: ./config20.ini
# Created config file: ./config21.ini
# Created config file: ./config22.ini
# Created config file: ./config23.ini
# Created config file: ./config24.ini
# Created config file: ./config25.ini
# Created config file: ./config26.ini
# Created config file: ./config27.ini
# Created config file: ./config28.ini
# Created config file: ./config29.ini
# Created config file: ./config30.ini
# Created config file: ./config31.ini
# Created config file: ./config32.ini
# Created config file: ./config33.ini
# Created config file: ./config34.ini
# Created config file: ./config35.ini
# Created config file: ./config36.ini
# Created config file: ./config37.ini
# Created config file: ./config38.ini
# Created config file: ./config39.ini
# Created config file: ./config40.ini
# Created config file: ./config41.ini
# Created config file: ./config42.ini
# Created config file: ./config43.ini
# Created config file: ./config44.ini
# Created config file: ./config45.ini
# Created config file: ./config46.ini
# Created config file: ./config47.ini
# Created config file: ./config48.ini
# Created config file: ./config49.ini
# Created config file: ./config50.ini
# Created config file: ./config51.ini
# Created config file: ./config52.ini
# Created config file: ./config53.ini
# Created config file: ./config54.ini
# Created config file: ./config55.ini
# Created config file: ./config56.ini
# Created config file: ./config57.ini
# Created config file: ./config58.ini
# Created config file: ./config59.ini
# Created config file: ./config60.ini
# Created config file: ./config61.ini
# Created config file: ./config62.ini
# Created config file: ./config63.ini
# Created config file: ./config64.ini
# Created config file: ./config65.ini
# Created config file: ./config66.ini
# Created config file: ./config67.ini
# Created config file: ./config68.ini
# Created config file: ./config69.ini
# Created config file: ./config70.ini
# Created config file: ./config71.ini
# Created config file: ./config72.ini
# Created config file: ./config73.ini
# Created config file: ./config74.ini
# Created config file: ./config75.ini
# Created config file: ./config76.ini
# Created config file: ./config77.ini
# Created config file: ./config78.ini
# Created config file: ./config79.ini
# Created config file: ./config80.ini
# Created config file: ./config81.ini
# Created config file: ./config82.ini
# Created config file: ./config83.ini
# Created config file: ./config84.ini
# Created config file: ./config85.ini
# Created config file: ./config86.ini
# Created config file: ./config87.ini
# Created config file: ./config88.ini
# Created config file: ./config89.ini
# Created config file: ./config90.ini
# Created config file: ./config91.ini
# Created config file: ./config92.ini
# Created config file: ./config93.ini
# Created config file: ./config94.ini
# Created config file: ./config95.ini
# Created config file: ./config96.ini
# Created config file: ./config97.ini
# Created config file: ./config98.ini
# Created config file: ./config99.ini
# Created config file: ./config100.ini
# Created config file: ./config101.ini
# Created config file: ./config102.ini
# Created config file: ./config103.ini
# Created config file: ./config104.ini
# Created config file: ./config105.ini
# Created config file: ./config106.ini
# Created config file: ./config107.ini
# Created config file: ./config108.ini
# Created config file: ./config109.ini
# Created config file: ./config110.ini
# Created config file: ./config111.ini
# Created config file: ./config112.ini
# Created config file: ./config113.ini
# Created config file: ./config114.ini
# Created config file: ./config115.ini
# Created config file: ./config116.ini
# Created config file: ./config117.ini
# Created config file: ./config118.ini
# Created config file: ./config119.ini
# Created config file: ./config120.ini
# Created config file: ./config121.ini
# Created config file: ./config122.ini
# Created config file: ./config123.ini
# Created config file: ./config124.ini
# Created config file: ./config125.ini
# Created config file: ./config126.ini
# Created config file: ./config127.ini
# Created config file: ./config128.ini
# Created config file: ./config129.ini
# Created config file: ./config130.ini
# Created config file: ./config131.ini
# Created config file: ./config132.ini
# Created config file: ./config133.ini
# Created config file: ./config134.ini
# Created config file: ./config135.ini
# Created config file: ./config136.ini
# Created config file: ./config137.ini
# Created config file: ./config138.ini
# Created config file: ./config139.ini
# Created config file: ./config140.ini
# Created config file: ./config141.ini
# Created config file: ./config142.ini
# Created config file: ./config143.ini
# Created config file: ./config144.ini
# Created config file: ./config145.ini
# Created config file: ./config146.ini
# Created config file: ./config147.ini
# Created config file: ./config148.ini
# Created config file: ./config149.ini
# Created config file: ./config150.ini
# Created config file: ./config151.ini
# Created config file: ./config152.ini
# Created config file: ./config153.ini
# Created config file: ./config154.ini
# Created config file: ./config155.ini
# Created config file: ./config156.ini
# Created config file: ./config157.ini
# Created config file: ./config158.ini
# Created config file: ./config159.ini
# Created config file: ./config160.ini
